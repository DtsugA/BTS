# %%
import pandas as pd
import numpy as np

# library for text preprocessing
import re
import nltk

#nltk.download('stopwords')

from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import RegexpTokenizer
#nltk.download('wordnet') 


from nltk.stem.wordnet import WordNetLemmatizer

# %%
# selected column headers we want to use 
new_headers = ['Tags', 'Score']
df = pd.read_csv("dl2020.csv", header=0)
# remove unwanted columns keep selected headers
dataset = pd.DataFrame(df, columns=new_headers)

#dataset

# %%
import re
# convert to lowercase
dataset['Tags'] = dataset['Tags'].str.lower()

# convert desc to string
dataset['Tags'] = dataset['Tags'].astype(str)

dataset['New_Tags'] = dataset['Tags'].apply(lambda x: ''.join([item for item in re.sub(r'.', '', x, count = 1)]))

dataset.head(10)
# Out:
#                                                 Tags  Score  \
# 0  <python><machine-learning><deep-learning><pyto...      0
# 1       <python><tensorflow><deep-learning><version>      0
# 2  <python><machine-learning><deep-learning><pyto...      0
# 3   <java><deep-learning><resources><deeplearning4j>      1
# 4  <python><tensorflow><deep-learning><neural-net...      4
# 5  <python><tensorflow><deep-learning><neural-net...      4
# 6  <tensorflow><keras><deep-learning><nlp><huggin...      2
# 7   <c#><asp.net><sharepoint><sharepoint-2013><csom>      0
# 8   <python><tensorflow><keras><conv-neural-network>     -2
# 9  <image-processing><keras><deep-learning...      0
#
#                                             New_Tags
# 0  python><machine-learning><deep-learning><pytorch>
# 1        python><tensorflow><deep-learning><version>
# 2  python><machine-learning><deep-learning><pytorch>
# 3    java><deep-learning><resources><deeplearning4j>
# 4  python><tensorflow><deep-learning><neural-netw...
# 5  python><tensorflow><deep-learning><neural-netw...
# 6  tensorflow><keras><deep-learning><nlp><hugging...
# 7    c#><asp.net><sharepoint><sharepoint-2013><csom>
# 8    python><tensorflow><keras><conv-neural-network>
# 9  image><image-processing><keras><deep-learning>...

# %%
product_headers = ['New_Tags', 'Score']
export_dataset = pd.DataFrame(dataset, columns=product_headers)
 
export_dataset
export_dataset.to_csv('Cdl2020.csv', encoding='utf-8', index=False)

# %%
# selected column headers we want to use 
new_headers = ['New_Tags', 'Score']
df = pd.read_csv("Cdl2020.csv", header=0)
# remove unwanted columns keep selected headers
dataset = pd.DataFrame(df, columns=new_headers)

dataset
# Out:
#                                                 New_Tags  Score
# 0      python><machine-learning><deep-learning><pytorch>      0
# 1            python><tensorflow><deep-learning><version>      0
# 2      python><machine-learning><deep-learning><pytorch>      0
# 3        java><deep-learning><resources><deeplearning4j>      1
# 4      python><tensorflow><deep-learning><neural-netw...      4
# ...                                                  ...    ...
# 10479  tensorflow><keras><deep-learning><activation-f...      0
# 10480          python><tensorflow><keras><deep-learning>     -1
# 10481  machine-learning><deep-learning><neural-networ...     -2
# 10482                                html><font-awesome>      0
# 10483    python><tensorflow><keras><lstm><tensorflow2.0>      0
#
# [10484 rows x 2 columns]

# %%
# convert desc to string
dataset['New_Tags'] = dataset['New_Tags'].astype(str)

dataset['Tags'] = dataset['New_Tags'].apply(lambda x: ''.join([item for item in x.split('>')]))

dataset.head(10)
# Out:
#                                             New_Tags  Score  \
# 0  python><machine-learning><deep-learning><pytorch>      0
# 1        python><tensorflow><deep-learning><version>      0
# 2  python><machine-learning><deep-learning><pytorch>      0
# 3    java><deep-learning><resources><deeplearning4j>      1
# 4  python><tensorflow><deep-learning><neural-netw...      4
# 5  python><tensorflow><deep-learning><neural-netw...      4
# 6  tensorflow><keras><deep-learning><nlp><hugging...      2
# 7    c#><asp.net><sharepoint><sharepoint-2013><csom>      0
# 8    python><tensorflow><keras><conv-neural-network>     -2
# 9  image><image-processing><keras><deep-learning>...      0
#
#                                                 Tags
# 0      python<machine-learning<deep-learning<pytorch
# 1            python<tensorflow<deep-learning<version
# 2      python<machine-learning<deep-learning<pytorch
# 3        java<deep-learning<resources<deeplearning4j
# 4  python<tensorflow<deep-learning<neural-network...
# 5  python<tensorflow<deep-learning<neural-network...
# 6  tensorflow<keras<deep-learning<nlp<huggingface...
# 7         c#<asp.net<sharepoint<sharepoint-2013<csom
# 8        python<tensorflow<keras<conv-neural-network
# 9  image<image-processing<keras<deep-learning<tra...

# %%
product_headers = ['Tags', 'Score']
export_dataset = pd.DataFrame(dataset, columns=product_headers)
 
export_dataset
export_dataset.to_csv('CleanedDL2020.csv', encoding='utf-8', index=False)
