# %%
import pandas as pd
import random
import os
import numpy as np
from tqdm import tqdm_notebook
from collections import Counter

from gensim.models import Word2Vec
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 10.0)
plt.rcParams.update({'font.size': 15})

# %%
path = 'CleanedML2020.csv'
df = pd.read_csv(path)
df.columns
df.head()
# Out:
#                                 Tags  Score
# 0  scikit-learn<svm<cross-validation      1
# 1                         python<svm      0
# 2                r<linear-regression      1
# 3                r<linear-regression      1
# 4  python<optimization<random-forest      0

# %%
tags = list(df['Tags'].unique())
all_tags = []
for tag in tqdm_notebook(tags):
    all_tags += tag.split('<')
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_39764\352278747.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for tag in tqdm_notebook(tags):
#   0%|          | 0/2369 [00:00<?, ?it/s]

# %%
count_tags = Counter(all_tags)
tags = pd.DataFrame([list(count_tags.keys()), list(count_tags.values())])
tags = tags.transpose()
tags.columns = ['tag', 'count']
tags = tags.sort_values(by='count', ascending=False)

# %%
plt.barh(list(tags['tag'])[:20], list(tags['count'])[:20])
plt.ylabel('Tags Used')
plt.xlabel('Tag Raw-Count')
plt.title('Top 20 Popular Tags')
plt.show()

# %%
ml = ['svm', 'logistic-regression', 'decision-tree', 'knn', 'naivebayes', 'random-forest', 'k-means', 'linear-regression', 'dimensionality-reduction']
x = []
y = []
for tag in ml:
    index = list(tags['tag']).index(tag)
    x.append(tag)
    y.append(list(tags['count'])[index])

# %%
plt.xticks(rotation='vertical')
plt.bar(x, y)
plt.ylabel('The Frequency of ML-related Skills')
plt.xlabel('ML-related Skills')
#plt.show()
plt.savefig("ml.pdf", bbox_inches='tight')
