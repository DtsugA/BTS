# %%
import pandas as pd
import numpy as np

# library for text preprocessing
import re
import nltk

#nltk.download('stopwords')

from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import RegexpTokenizer
#nltk.download('wordnet') 


from nltk.stem.wordnet import WordNetLemmatizer

# %%
# selected column headers we want to use 
new_headers = ['Tags', 'Score']
df = pd.read_csv("QueryResults_rq3.csv", header=0)
# remove unwanted columns keep selected headers
dataset = pd.DataFrame(df, columns=new_headers)

dataset
# Out:
#                                                    Tags  Score
# 0                                        <deepsecurity>      0
# 1                                 <xml><security><odoo>      0
# 2     <firebase><google-cloud-firestore><firebase-se...      0
# 3             <php><symfony><security><include><config>      0
# 4                           <symfony><symfony-security>      0
# ...                                                 ...    ...
# 4389       <java><spring><spring-boot><spring-security>      0
# 4390  <firebase><next.js><environment-variables><fir...      0
# 4391                          <spring-security><vaadin>      0
# 4392                             <security><npm><audit>      2
# 4393                 <node.js><content-security-policy>     -1
#
# [4394 rows x 2 columns]

# %%
import re
# convert to lowercase
dataset['Tags'] = dataset['Tags'].str.lower()

# convert desc to string
dataset['Tags'] = dataset['Tags'].astype(str)

dataset['New_Tags'] = dataset['Tags'].apply(lambda x: ''.join([item for item in re.sub(r'.', '', x, count = 1)]))

dataset.head(10)
# Out:
#                                                 Tags  Score  \
# 0                                     <deepsecurity>      0
# 1                              <xml><security><odoo>      0
# 2  <firebase><google-cloud-firestore><firebase-se...      0
# 3          <php><symfony><security><include><config>      0
# 4                        <symfony><symfony-security>      0
# 5  <firebase><firebase-realtime-database><firebas...      0
# 6  <angular><spring-boot><spring-mvc><spring-secu...     -1
# 7  <spring><spring-boot><spring-security><spring-...      1
# 8  <google-cloud-firestore><firebase-authenticati...      0
# 9        <android><security><google-cloud-functions>      0
#
#                                             New_Tags
# 0                                      deepsecurity>
# 1                               xml><security><odoo>
# 2  firebase><google-cloud-firestore><firebase-sec...
# 3           php><symfony><security><include><config>
# 4                         symfony><symfony-security>
# 5  firebase><firebase-realtime-database><firebase...
# 6  angular><spring-boot><spring-mvc><spring-secur...
# 7  spring><spring-boot><spring-security><spring-s...
# 8  google-cloud-firestore><firebase-authenticatio...
# 9         android><security><google-cloud-functions>

# %%
product_headers = ['New_Tags', 'Score']
export_dataset = pd.DataFrame(dataset, columns=product_headers)
 
export_dataset
export_dataset.to_csv('CleanedStack_rq3.csv', encoding='utf-8', index=False)

# %%
# selected column headers we want to use 
new_headers = ['New_Tags', 'Score']
df = pd.read_csv("CleanedStack_rq3.csv", header=0)
# remove unwanted columns keep selected headers
dataset = pd.DataFrame(df, columns=new_headers)

dataset
# Out:
#                                                New_Tags  Score
# 0                                         deepsecurity>      0
# 1                                  xml><security><odoo>      0
# 2     firebase><google-cloud-firestore><firebase-sec...      0
# 3              php><symfony><security><include><config>      0
# 4                            symfony><symfony-security>      0
# ...                                                 ...    ...
# 4389        java><spring><spring-boot><spring-security>      0
# 4390  firebase><next.js><environment-variables><fire...      0
# 4391                           spring-security><vaadin>      0
# 4392                              security><npm><audit>      2
# 4393                  node.js><content-security-policy>     -1
#
# [4394 rows x 2 columns]

# %%
# convert desc to string
dataset['New_Tags'] = dataset['New_Tags'].astype(str)

dataset['Tags'] = dataset['New_Tags'].apply(lambda x: ''.join([item for item in x.split('>')]))

dataset.head(10)
# Out:
#                                             New_Tags  Score  \
# 0                                      deepsecurity>      0
# 1                               xml><security><odoo>      0
# 2  firebase><google-cloud-firestore><firebase-sec...      0
# 3           php><symfony><security><include><config>      0
# 4                         symfony><symfony-security>      0
# 5  firebase><firebase-realtime-database><firebase...      0
# 6  angular><spring-boot><spring-mvc><spring-secur...     -1
# 7  spring><spring-boot><spring-security><spring-s...      1
# 8  google-cloud-firestore><firebase-authenticatio...      0
# 9         android><security><google-cloud-functions>      0
#
#                                                 Tags
# 0                                       deepsecurity
# 1                                  xml<security<odoo
# 2  firebase<google-cloud-firestore<firebase-security
# 3                php<symfony<security<include<config
# 4                           symfony<symfony-security
# 5  firebase<firebase-realtime-database<firebase-s...
# 6  angular<spring-boot<spring-mvc<spring-security...
# 7  spring<spring-boot<spring-security<spring-secu...
# 8  google-cloud-firestore<firebase-authentication...
# 9            android<security<google-cloud-functions

# %%
product_headers = ['Tags', 'Score']
export_dataset = pd.DataFrame(dataset, columns=product_headers)
 
export_dataset
export_dataset.to_csv('TagScore_rq3.csv', encoding='utf-8', index=False)
